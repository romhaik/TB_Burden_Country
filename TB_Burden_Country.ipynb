# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
hauwa=pd.read_csv('TB_Burden_Country.csv')
hauwa
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 0                  Afghanistan                                     AF
# 1                  Afghanistan                                     AF
# 2                  Afghanistan                                     AF
# 3                  Afghanistan                                     AF
# 4                  Afghanistan                                     AF
# ...                        ...                                    ...
# 5115                  Zimbabwe                                     ZW
# 5116                  Zimbabwe                                     ZW
# 5117                  Zimbabwe                                     ZW
# 5118                  Zimbabwe                                     ZW
# 5119                  Zimbabwe                                     ZW
#
#      ISO 3-character country/territory code  \
# 0                                       AFG
# ...

# %% [markdown]
# ### EXTRACTING NIGERIA FROM THE WHOLE DATA

# %%
HAUWA=hauwa.loc[[3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324]]
HAUWA
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 3302                   Nigeria                                     NG
# 3303                   Nigeria                                     NG
# 3304                   Nigeria                                     NG
# 3305                   Nigeria                                     NG
# 3306                   Nigeria                                     NG
# 3307                   Nigeria                                     NG
# 3308                   Nigeria                                     NG
# 3309                   Nigeria                                     NG
# 3310                   Nigeria                                     NG
# 3311                   Nigeria                                     NG
# 3312                   Nigeria                                     NG
# 3313                   Nigeria                                     NG
# ...

# %%
hauwa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5120 entries, 0 to 5119
# Data columns (total 47 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Country or territory name                                                                       5120 non-null   object
#  1   ISO 2-character country/territory code                                                          5096 non-null   object
#  2   ISO 3-character country/territory code                                                          5120 non-null   object
#  3   ISO numeric country/territory code                                                              5120 non-null   int64
#  4   Region                                                                                          5120 non-null   object
# ...

# %%
hauwa.describe()
# Out:
#        ISO numeric country/territory code         Year  \
# count                         5120.000000  5120.000000
# mean                           433.576563  2001.549023
# std                            255.116018     6.933272
# min                              4.000000  1990.000000
# 25%                            212.000000  1996.000000
# 50%                            430.000000  2002.000000
# 75%                            646.000000  2008.000000
# max                            894.000000  2013.000000
#
#        Estimated total population number  \
# count                       5.120000e+03
# mean                        2.915671e+07
# std                         1.183725e+08
# min                         1.129000e+03
# 25%                         5.601190e+05
# 50%                         5.172118e+06
# 75%                         1.752404e+07
# max                         1.385567e+09
#
#        Estimated prevalence of TB (all forms) per 100 000 population  \
# ...

# %% [markdown]
# ### METHOD OF VIEWING NANS

# %%
HAUWA[HAUWA['Method to derive incidence estimates'].isnull()]
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 3302                   Nigeria                                     NG
# 3303                   Nigeria                                     NG
# 3304                   Nigeria                                     NG
# 3305                   Nigeria                                     NG
# 3306                   Nigeria                                     NG
# 3307                   Nigeria                                     NG
# 3308                   Nigeria                                     NG
# 3309                   Nigeria                                     NG
# 3310                   Nigeria                                     NG
# 3311                   Nigeria                                     NG
# 3312                   Nigeria                                     NG
# 3313                   Nigeria                                     NG
# ...

# %% [markdown]
# ### METHOD OF EXTRACTING COLUMNS THAT CONTAIN NANS

# %%
HAUWA[['Method to derive incidence estimates','Method to derive TBHIV estimates']]
# Out:
#      Method to derive incidence estimates  Method to derive TBHIV estimates
# 3302                                  NaN                               NaN
# 3303                                  NaN                               NaN
# 3304                                  NaN                               NaN
# 3305                                  NaN                               NaN
# 3306                                  NaN                               NaN
# 3307                                  NaN                               NaN
# 3308                                  NaN                               NaN
# 3309                                  NaN                               NaN
# 3310                                  NaN                               NaN
# 3311                                  NaN                               NaN
# 3312                                  NaN                               NaN
# ...

# %% [markdown]
# ### USING COUNTRY OR TERRITORY NAME AS INDEX

# %%
HAUWA
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 3302                   Nigeria                                     NG
# 3303                   Nigeria                                     NG
# 3304                   Nigeria                                     NG
# 3305                   Nigeria                                     NG
# 3306                   Nigeria                                     NG
# 3307                   Nigeria                                     NG
# 3308                   Nigeria                                     NG
# 3309                   Nigeria                                     NG
# 3310                   Nigeria                                     NG
# 3311                   Nigeria                                     NG
# 3312                   Nigeria                                     NG
# 3313                   Nigeria                                     NG
# ...

# %%
HAUWA.set_index(['Country or territory name'])
# Out:
#                           ISO 2-character country/territory code  \
# Country or territory name
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# ...

# %% [markdown]
# ### METHOD OF DELETING NAN COLUMNS

# %%
HAUWA=HAUWA.drop("Method to derive TBHIV estimates",1)
HAUWA
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 3302                   Nigeria                                     NG
# 3303                   Nigeria                                     NG
# 3304                   Nigeria                                     NG
# 3305                   Nigeria                                     NG
# 3306                   Nigeria                                     NG
# 3307                   Nigeria                                     NG
# 3308                   Nigeria                                     NG
# 3309                   Nigeria                                     NG
# 3310                   Nigeria                                     NG
# 3311                   Nigeria                                     NG
# 3312                   Nigeria                                     NG
# 3313                   Nigeria                                     NG
# ...

# %%
HAUWA.set_index(['Country or territory name'])
# Out:
#                           ISO 2-character country/territory code  \
# Country or territory name
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# Nigeria                                                       NG
# ...

# %%
HAUWA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 3302 to 3324
# Data columns (total 46 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Country or territory name                                                                       23 non-null     object
#  1   ISO 2-character country/territory code                                                          23 non-null     object
#  2   ISO 3-character country/territory code                                                          23 non-null     object
#  3   ISO numeric country/territory code                                                              23 non-null     int64
#  4   Region                                                                                          23 non-null     object
# ...

# %% [markdown]
# ### VISUALLIZING THE DATAS

# %%
HAUWAcon=pd.concat([HAUWA['Estimated total population number']],axis=1)
HAUWAcon.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='Estimated HIV in incident TB (percent)', y='Year', data=HAUWA, orient='h')
### both 2011 and 2012 has the highest Estimated HIV in incident TB (percent) and start decreasing from 2013 according to Data here and the lowest year is 1991 for Estimated HIV in incident TB (percent)
# Out:
# <AxesSubplot:xlabel='Estimated HIV in incident TB (percent)', ylabel='Year'>

# %%
sns.barplot(x='Estimated number of deaths from TB (all forms, excluding HIV)', y='Year', data=HAUWA, orient='h')
### the year that has the highest number for Estimated number of deaths from TB (all forms, excluding HIV) are 2012 and 2013 and the year that has the lowes number is 1991
# Out:
# <AxesSubplot:xlabel='Estimated number of deaths from TB (all forms, excluding HIV)', ylabel='Year'>

# %%
HAUWAcon=pd.concat([HAUWA['Estimated number of deaths from TB in people who are HIV-positive'],HAUWA['Estimated number of incident cases (all forms)']],axis=1)
HAUWAcon.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
 sns.barplot(x='Estimated number of deaths from TB in people who are HIV-positive', y='Year', data=HAUWA, orient='h')
    ### the year that has the highest number of Estimated number of deaths from TB in people who are HIV-positive are 2011 and 2012 but start dropping in 2013 and the year that has the lowest number is 1991
# Out:
# <AxesSubplot:xlabel='Estimated number of deaths from TB in people who are HIV-positive', ylabel='Year'>

# %%
sns.barplot(x='Estimated number of incident cases (all forms)', y='Year', data=HAUWA, orient='h')
### the year that has the highest number of Estimated number of incident cases (all forms) is 2013 and the year that has the lowest number of Estimated number of incident cases (all forms) is 1991
# Out:
# <AxesSubplot:xlabel='Estimated number of incident cases (all forms)', ylabel='Year'>
